# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
r2_scores = [0.7369, 0.6828, 0.8267, 0.018125, 0.711490, 0.01845, 0.8098, 
             0.7973, 0.8688, 0.575, 0.887866, 0.8893, 0.9942, 0.8834, 
             0.9958, 0.882, 0.9207, 0.08100, 0.7141, 0.8535, 0.9983, 
             0.9267, 0.9987, 0.9990, 0.9986, 0.9819, 0.9589, 0.9994, 
             0.9565, 0.9999, 0.6933, 0.8894, 0.4900, 0.7496, 0.6928, 
             0.2849, 0.1407, 0.6824, 0.8571, 0.4441, 0.7607, 0.6753, 
             0.9921, 0.9092, 0.8621, 0.9248, 0.9992, 0.9811, 0.9992, 
             0.9997, 0.0528, 0.5622, 0.6689, 0.6856, 0.5783, 0.6928, 
             0.9875, 0.9119, 0.9709, 0.9447, 0.9705, 0.7960, 0.8292, 
             0.9531, 0.9065, 0.5314, 0.9985, 0.8757, 0.5354, 0.9967, 
             0.7536, 0.7519, 0.4912, 0.1114, 0.7268]

# %%
mean_r2 = np.mean(r2_scores)
plt.figure(figsize = (8, 5))
plt.hist(r2_scores, bins = 15)
plt.axvline(mean_r2, linestyle = 'dashed', linewidth = 2, label = f"mean = {mean_r2:.2f}")

plt.xlabel("R² Score", fontsize = 15)
plt.ylabel("Frequency", fontsize = 15)
plt.title("Distribution of Cross-Validation R² Scores", fontsize = 20)
plt.legend()

plt.savefig("r2_distribution.png", dpi = 300)

plt.tight_layout()
